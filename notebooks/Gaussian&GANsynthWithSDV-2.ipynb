# %%
# !pip install synthcity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting synthcity
#   Downloading synthcity-0.2.5-py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.8/345.8 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from synthcity) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.9/dist-packages (from synthcity) (1.2.2)
# Requirement already satisfied: pandas<2.0,>=1.3 in /usr/local/lib/python3.9/dist-packages (from synthcity) (1.5.3)
# Collecting xgbse
#   Downloading xgbse-0.2.3-py3-none-any.whl (35 kB)
# Collecting monai
#   Downloading monai-1.1.0-202212191849-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 35.3 MB/s eta 0:00:00
# Collecting redis
#   Downloading redis-4.5.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 27.2 MB/s eta 0:00:00
# Collecting pykeops
#   Downloading pykeops-2.1.2.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting optuna>=3.1
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 40.4 MB/s eta 0:00:00
# Collecting decaf-synthetic-data>=0.1.6
#   Downloading decaf_synthetic_data-0.1.6-py3-none-any.whl (9.1 kB)
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 kB 57.3 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from synthcity) (2.2.1)
# Collecting fflows
#   Downloading fflows-0.0.3-py3-none-any.whl (19 kB)
# Collecting tsai
#   Downloading tsai-0.3.6-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.9/298.9 kB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from synthcity) (1.22.4)
# Collecting opacus>=1.3
#   Downloading opacus-1.4.0-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 27.5 MB/s eta 0:00:00
# Collecting nflows>=0.14
#   Downloading nflows-0.14.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting loguru
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.8 MB/s eta 0:00:00
# Collecting pgmpy
#   Downloading pgmpy-0.1.22-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 68.2 MB/s eta 0:00:00
# Collecting pycox
#   Downloading pycox-0.2.3-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: xgboost in /usr/local/lib/python3.9/dist-packages (from synthcity) (1.7.5)
# Collecting torch<2.0,>=1.10
#   Downloading torch-1.13.1-cp39-cp39-manylinux1_x86_64.whl (887.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from synthcity) (1.10.7)
# Collecting geomloss
#   Downloading geomloss-0.2.5.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from synthcity) (4.65.0)
# Collecting lifelines>=0.27
#   Downloading lifelines-0.27.4-py3-none-any.whl (349 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.7/349.7 kB 38.9 MB/s eta 0:00:00
# Requirement already satisfied: torchtext>=0.10 in /usr/local/lib/python3.9/dist-packages (from decaf-synthetic-data>=0.1.6->synthcity) (0.15.1)
# Collecting networkx<3.0,>=2.0
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 93.1 MB/s eta 0:00:00
# Collecting pytorch-lightning<2.0
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.9/dist-packages (from lifelines>=0.27->synthcity) (3.7.1)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.9/dist-packages (from lifelines>=0.27->synthcity) (1.5)
# Collecting formulaic>=0.2.2
#   Downloading formulaic-0.5.2-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 12.5 MB/s eta 0:00:00
# Collecting autograd-gamma>=0.3
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from nflows>=0.14->synthcity) (2.12.1)
# Requirement already satisfied: opt-einsum>=3.3.0 in /usr/local/lib/python3.9/dist-packages (from opacus>=1.3->synthcity) (3.3.0)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna>=3.1->synthcity) (6.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna>=3.1->synthcity) (2.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna>=3.1->synthcity) (23.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.3-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 26.4 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2.0,>=1.3->synthcity) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2.0,>=1.3->synthcity) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0->synthcity) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0->synthcity) (1.2.0)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch<2.0,>=1.10->synthcity) (4.5.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 82.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0,>=1.10->synthcity) (67.6.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0,>=1.10->synthcity) (0.40.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from pgmpy->synthcity) (0.13.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/dist-packages (from pgmpy->synthcity) (3.0.9)
# Collecting torchtuples>=0.2.0
#   Downloading torchtuples-0.2.2-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.44 in /usr/local/lib/python3.9/dist-packages (from pycox->synthcity) (0.56.4)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.9/dist-packages (from pycox->synthcity) (2.27.1)
# Collecting py7zr>=0.11.3
#   Downloading py7zr-0.20.4-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from pycox->synthcity) (3.8.0)
# Collecting feather-format>=0.4.0
#   Downloading feather-format-0.4.1.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pybind11
#   Downloading pybind11-2.10.4-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 31.1 MB/s eta 0:00:00
# Collecting keopscore==2.1.2
#   Downloading keopscore-2.1.2.tar.gz (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: psutil>=5.4.8 in /usr/local/lib/python3.9/dist-packages (from tsai->synthcity) (5.9.4)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from tsai->synthcity) (0.10.1)
# Requirement already satisfied: fastai>=2.7.12 in /usr/local/lib/python3.9/dist-packages (from tsai->synthcity) (2.7.12)
# Collecting pyts>=0.12.0
#   Downloading pyts-0.12.0-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 93.2 MB/s eta 0:00:00
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.9/dist-packages (from autograd>=1.5->lifelines>=0.27->synthcity) (0.18.3)
# Requirement already satisfied: pip in /usr/local/lib/python3.9/dist-packages (from fastai>=2.7.12->tsai->synthcity) (23.0.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from fastai>=2.7.12->tsai->synthcity) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /usr/local/lib/python3.9/dist-packages (from fastai>=2.7.12->tsai->synthcity) (1.5.29)
# Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.9/dist-packages (from fastai>=2.7.12->tsai->synthcity) (8.4.0)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.9/dist-packages (from fastai>=2.7.12->tsai->synthcity) (3.5.1)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from fastai>=2.7.12->tsai->synthcity) (0.15.1+cu118)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.9/dist-packages (from fastai>=2.7.12->tsai->synthcity) (1.0.3)
# Requirement already satisfied: pyarrow>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from feather-format>=0.4.0->pycox->synthcity) (9.0.0)
# Collecting interface-meta>=1.2.0
#   Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Collecting astor>=0.8
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.9/dist-packages (from formulaic>=0.2.2->lifelines>=0.27->synthcity) (1.14.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines>=0.27->synthcity) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines>=0.27->synthcity) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines>=0.27->synthcity) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines>=0.27->synthcity) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0->lifelines>=0.27->synthcity) (1.4.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.44->pycox->synthcity) (0.39.1)
# Collecting pyppmd<1.1.0,>=0.18.1
#   Downloading pyppmd-1.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 19.5 MB/s eta 0:00:00
# Collecting texttable
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Collecting brotli>=1.0.9
#   Downloading Brotli-1.0.9-cp39-cp39-manylinux1_x86_64.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.2/357.2 kB 39.4 MB/s eta 0:00:00
# Collecting pyzstd>=0.14.4
#   Downloading pyzstd-0.15.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.4/390.4 kB 42.0 MB/s eta 0:00:00
# Collecting pybcj>=0.6.0
#   Downloading pybcj-1.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 7.0 MB/s eta 0:00:00
# Collecting pycryptodomex>=3.6.6
#   Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.9 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64>=0.3.1
#   Downloading inflate64-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas<2.0,>=1.3->synthcity) (1.16.0)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 51.3 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.6.0.post0
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (2023.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pycox->synthcity) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pycox->synthcity) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pycox->synthcity) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->pycox->synthcity) (2022.12.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.1->synthcity) (2.0.2)
# Collecting torchtext>=0.10
#   Downloading torchtext-0.14.1-cp39-cp39-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 77.5 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->pgmpy->synthcity) (0.5.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (1.53.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (2.17.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (2.2.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (3.20.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nflows>=0.14->synthcity) (1.4.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.3 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->nflows>=0.14->synthcity) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.0->lifelines>=0.27->synthcity) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard->nflows>=0.14->synthcity) (6.2.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (2.4.6)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (8.1.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (6.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (3.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai>=2.7.12->tsai->synthcity) (3.1.2)
# Collecting torchvision>=0.8.2
#   Downloading torchvision-0.15.1-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 105.5 MB/s eta 0:00:00
#   Downloading torchvision-0.14.1-cp39-cp39-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 71.1 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard->nflows>=0.14->synthcity) (2.1.2)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 17.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 20.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (22.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->nflows>=0.14->synthcity) (3.2.2)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.7.12->tsai->synthcity) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.7.12->tsai->synthcity) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai>=2.7.12->tsai->synthcity) (8.1.3)
# Building wheels for collected packages: nflows, geomloss, pykeops, keopscore, autograd-gamma, feather-format
#   Building wheel for nflows (setup.py) ... done
#   Created wheel for nflows: filename=nflows-0.14-py3-none-any.whl size=53670 sha256=76864be091464b0743be0370b08838008e72c3c9aa8f6893412126086e6953e7
#   Stored in directory: /root/.cache/pip/wheels/3b/88/52/cbd4ed0597b48916de3de19b28d7297c72595f56085068c772
#   Building wheel for geomloss (setup.py) ... done
#   Created wheel for geomloss: filename=geomloss-0.2.5-py3-none-any.whl size=32068 sha256=b2ec9603bc41358094bdb03cd7af35cfbb8a37c7a4844cb830660be7ff0198c5
#   Stored in directory: /root/.cache/pip/wheels/91/5f/d7/0dbc6074929fc09f1280db596bfe0e2b59e5790bdfbaefe017
#   Building wheel for pykeops (setup.py) ... done
#   Created wheel for pykeops: filename=pykeops-2.1.2-py3-none-any.whl size=114095 sha256=e9446bdc0d73df905b1d86421f7cced4fa2b493becefb9305d76d19c9ca777eb
#   Stored in directory: /root/.cache/pip/wheels/61/a1/b9/156d48595487f5df04d1c5eee5ec01f3330ae2debece7ca6fe
#   Building wheel for keopscore (setup.py) ... done
#   Created wheel for keopscore: filename=keopscore-2.1.2-py3-none-any.whl size=146469 sha256=f01908370d0bd7c97e1797496a4d51f15a114e6289e17df4ed4f513a3ef00680
#   Stored in directory: /root/.cache/pip/wheels/93/53/76/4a583149d55824e0d0a30a303cc5cd6ae1d4545d3f61f346c9
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4049 sha256=a6d0e30ed81e44d1a7dadccac592feaf4e49f1211b6e353b3f5a99c22720d592
#   Stored in directory: /root/.cache/pip/wheels/a8/03/64/8557323821d25118c3a2dc1646996f7a962a8970d4b7d22473
#   Building wheel for feather-format (setup.py) ... done
#   Created wheel for feather-format: filename=feather_format-0.4.1-py3-none-any.whl size=2455 sha256=8dc69c5572e4df33111b763b47a5e38554bd58fc93bf128485793fddc37bbf44
#   Stored in directory: /root/.cache/pip/wheels/e3/dc/eb/3a9468e9322c8284d7a53eab23e7a4bab6f271fff7a5871e2f
# Successfully built nflows geomloss pykeops keopscore autograd-gamma feather-format
# Installing collected packages: texttable, brotli, slicer, pyzstd, pyppmd, pycryptodomex, pybind11, pybcj, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, networkx, multivolumefile, multidict, Mako, loguru, lightning-utilities, keopscore, interface-meta, inflate64, geomloss, frozenlist, colorlog, cmaes, async-timeout, astor, yarl, redis, pykeops, py7zr, nvidia-cudnn-cu11, feather-format, autograd-gamma, alembic, aiosignal, torchtuples, torch, shap, pyts, optuna, formulaic, aiohttp, torchvision, torchtext, torchmetrics, pycox, pgmpy, opacus, monai, lifelines, fflows, xgbse, pytorch-lightning, nflows, tsai, decaf-synthetic-data, synthcity
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed Mako-1.2.4 aiohttp-3.8.4 aiosignal-1.3.1 alembic-1.10.3 astor-0.8.1 async-timeout-4.0.2 autograd-gamma-0.5.0 brotli-1.0.9 cmaes-0.9.1 colorlog-6.7.0 decaf-synthetic-data-0.1.6 feather-format-0.4.1 fflows-0.0.3 formulaic-0.5.2 frozenlist-1.3.3 geomloss-0.2.5 inflate64-0.3.1 interface-meta-1.3.0 keopscore-2.1.2 lifelines-0.27.4 lightning-utilities-0.8.0 loguru-0.7.0 monai-1.1.0 multidict-6.0.4 multivolumefile-0.2.3 networkx-2.8.8 nflows-0.14 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 opacus-1.4.0 optuna-3.1.1 pgmpy-0.1.22 py7zr-0.20.4 pybcj-1.0.1 pybind11-2.10.4 pycox-0.2.3 pycryptodomex-3.17 pykeops-2.1.2 pyppmd-1.0.0 pytorch-lightning-1.9.4 pyts-0.12.0 pyzstd-0.15.6 redis-4.5.4 shap-0.41.0 slicer-0.0.7 synthcity-0.2.5 texttable-1.6.7 torch-1.13.1 torchmetrics-0.11.4 torchtext-0.14.1 torchtuples-0.2.2 torchvision-0.14.1 tsai-0.3.6 xgbse-0.2.3 yarl-1.8.2

# %%
# !pip install sdv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sdv
#   Downloading sdv-1.0.0-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.1/114.1 kB 2.4 MB/s eta 0:00:00
# Collecting copulas<0.9,>=0.8.0
#   Downloading copulas-0.8.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3.0,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from sdv) (2.2.1)
# Collecting rdt<2,>=1.3.0
#   Downloading rdt-1.3.0-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from sdv) (1.22.4)
# Requirement already satisfied: pandas<2,>=1.1.3 in /usr/local/lib/python3.9/dist-packages (from sdv) (1.5.3)
# Collecting ctgan<0.8,>=0.7.1
#   Downloading ctgan-0.7.1-py2.py3-none-any.whl (26 kB)
# Collecting deepecho<0.5,>=0.4.0
#   Downloading deepecho-0.4.0-py2.py3-none-any.whl (28 kB)
# Collecting botocore<2,>=1.18
#   Downloading botocore-1.29.111-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 65.0 MB/s eta 0:00:00
# Collecting sdmetrics<0.10,>=0.9.1
#   Downloading sdmetrics-0.9.2-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.7/140.7 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.9/dist-packages (from sdv) (4.65.0)
# Requirement already satisfied: graphviz<1,>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from sdv) (0.20.1)
# Collecting Faker<15,>=10
#   Downloading Faker-14.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.8 MB/s eta 0:00:00
# Collecting boto3<2,>=1.15.0
#   Downloading boto3-1.26.111-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 645.3 kB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 8.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/dist-packages (from botocore<2,>=1.18->sdv) (1.26.15)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/dist-packages (from botocore<2,>=1.18->sdv) (2.8.2)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from copulas<0.9,>=0.8.0->sdv) (3.7.1)
# Requirement already satisfied: scipy<2,>=1.5.4 in /usr/local/lib/python3.9/dist-packages (from copulas<0.9,>=0.8.0->sdv) (1.10.1)
# Collecting packaging<22,>=20
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: torch<2,>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from ctgan<0.8,>=0.7.1->sdv) (1.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2,>=1.1.3->sdv) (2022.7.1)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /usr/local/lib/python3.9/dist-packages (from rdt<2,>=1.3.0->sdv) (1.2.2)
# Requirement already satisfied: psutil<6,>=5.7 in /usr/local/lib/python3.9/dist-packages (from rdt<2,>=1.3.0->sdv) (5.9.4)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.9/dist-packages (from sdmetrics<0.10,>=0.9.1->sdv) (5.13.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (5.12.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly<6,>=5.10.0->sdmetrics<0.10,>=0.9.1->sdv) (8.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.18->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<2,>=0.24->rdt<2,>=1.3.0->sdv) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<2,>=0.24->rdt<2,>=1.3.0->sdv) (3.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv) (11.7.99)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.9/dist-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv) (8.5.0.96)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv) (0.40.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.8.0->ctgan<0.8,>=0.7.1->sdv) (67.6.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (3.15.0)
# Installing collected packages: packaging, jmespath, Faker, botocore, s3transfer, rdt, copulas, sdmetrics, deepecho, ctgan, boto3, sdv
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
# Successfully installed Faker-14.2.1 boto3-1.26.111 botocore-1.29.111 copulas-0.8.0 ctgan-0.7.1 deepecho-0.4.0 jmespath-1.0.1 packaging-21.3 rdt-1.3.0 s3transfer-0.6.0 sdmetrics-0.9.2 sdv-1.0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import os
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from synthcity.plugins import Plugins
from sdv.metadata import SingleTableMetadata
from sdv.single_table import GaussianCopulaSynthesizer, CTGANSynthesizer
from sklearn.model_selection import train_test_split

FEATURE_COLUMNS = [
    'Type',
    'Air temperature [K]',
    'Process temperature [K]',
    'Rotational speed [rpm]', 
    'Torque [Nm]',
    'Tool wear [min]'
]

LABEL_A = "Target"
LABEL_B = "Failure Type"

FEATURES_AND_LABEL = [
    'Type',
    'Air temperature [K]',
    'Process temperature [K]',
    'Rotational speed [rpm]', 
    'Torque [Nm]',
    'Tool wear [min]',
    'Target'

]

K_FOLDS = 5
TEST_SPLIT_SIZE = 0.25

PERCENTAGE_ADDED_SYNTHETIC_DATA = 0.5 # 1 = +100% positive samples

GENERATE_KWARGS = dict(
    uniformization_ratio=0,
    stretch_factor=1
)

SEEDS = (10,)

def set_seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)



# def get_synthia_independence_copula(X_train, y_train):
#     generator = syn.CopulaDataGenerator(verbose=False)
#     mask = (y_train == 1).ravel() # mask for positive samples
#     generator.fit(np.hstack((X_train[mask], y_train[mask].reshape(-1, 1))), copula=syn.IndependenceCopula())
#     return generator,mask

# def get_synthia_gaussian_copula(X_train, y_train):
#     generator = syn.CopulaDataGenerator(verbose=False)
#     mask = (y_train == 1).ravel() # mask for positive samples
#     parameterizer = syn.QuantileParameterizer(n_quantiles=100)
        
#     generator.fit(np.hstack((X_train[mask], y_train[mask].reshape(-1, 1))), copula=syn.GaussianCopula(), parameterize_by=parameterizer)
#     return generator,mask

# %%
df = (
    pd.read_csv("/content/predictive_maintenance.csv", )
    .assign(
        Type=lambda x: LabelEncoder().fit_transform(x["Type"])
    )
)
df.head()
# Out:
#    UDI Product ID  Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860     2                298.1                    308.6
# 1    2     L47181     1                298.2                    308.7
# 2    3     L47182     1                298.1                    308.5
# 3    4     L47183     1                298.2                    308.6
# 4    5     L47184     1                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %% [markdown]
# # Copula with SDV

# %%
df = df.loc[:, FEATURES_AND_LABEL]
df.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     2                298.1                    308.6                    1551
# 1     1                298.2                    308.7                    1408
# 2     1                298.1                    308.5                    1498
# 3     1                298.2                    308.6                    1433
# 4     1                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target
# 0         42.8                0       0
# 1         46.3                3       0
# 2         49.4                5       0
# 3         39.5                7       0
# 4         40.0                9       0

# %% [markdown]
# ## Gaussian Copula

# %%
#chosing data to fit
X_train, X_test, y_train, y_test = train_test_split(
    df.loc[:, FEATURE_COLUMNS], df.loc[:, LABEL_A],
    test_size=0.25, random_state=20
)
train_indexes = X_train.index

df_gen_positives = df.loc[train_indexes, :]
df_gen_positives = df_gen_positives[df[LABEL_A] == 1]
#fitting the synthesizer
#Creating GaussianCopulaSynthesizer object
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=df_gen_positives)
Gaussian = GaussianCopulaSynthesizer(metadata, default_distribution='norm')
Gaussian.fit(df_gen_positives)
generated_data = Gaussian.sample(num_rows = len(df_gen_positives))

#training RandomForest
X_train_syn = np.vstack((X_train, generated_data.loc[:, FEATURE_COLUMNS]))
y_train_syn = np.hstack((y_train, generated_data.loc[:, LABEL_A]))
clf_syn = RandomForestClassifier(random_state=20)
clf_syn = clf_syn.fit(X_train_syn, y_train_syn)
# Evaluate classifier on balanced data
y_pred_syn = clf_syn.predict(X_test)
clf_report_syn = classification_report(y_test, y_pred_syn)
clf_conf_matrix_syn = confusion_matrix(y_test, y_pred_syn)
one_metrics_syn = precision_recall_fscore_support(y_test, y_pred_syn, average="binary")

# %%
print(one_metrics_syn)
# Out:
# (0.875, 0.5975609756097561, 0.7101449275362318, None)

# %% [markdown]
# ## CTGAN

# %%
#chosing data to fit
X_train, X_test, y_train, y_test = train_test_split(
    df.loc[:, FEATURE_COLUMNS], df.loc[:, LABEL_A],
    test_size=0.25, random_state=20
)
train_indexes = X_train.index

df_gen_positives = df.loc[train_indexes, :]
df_gen_positives = df_gen_positives[df[LABEL_A] == 1]

#Creating CTGANSynthesizer object
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=df_gen_positives)
CTGAN = CTGANSynthesizer(metadata)
#fitting the synthesizer
CTGAN.fit(df_gen_positives)
generated_data = CTGAN.sample(num_rows = len(df_gen_positives))

#training RandomForest
X_train_syn = np.vstack((X_train, generated_data.loc[:, FEATURE_COLUMNS]))
y_train_syn = np.hstack((y_train, generated_data.loc[:, LABEL_A]))
clf_syn = RandomForestClassifier(random_state=20)
clf_syn = clf_syn.fit(X_train_syn, y_train_syn)
# Evaluate classifier on balanced data
y_pred_syn = clf_syn.predict(X_test)
clf_report_syn = classification_report(y_test, y_pred_syn)
clf_conf_matrix_syn = confusion_matrix(y_test, y_pred_syn)
one_metrics_syn = precision_recall_fscore_support(y_test, y_pred_syn, average="binary")
print(one_metrics_syn)
# Out:
# (0.9245283018867925, 0.5975609756097561, 0.7259259259259259, None)

# %% [markdown]
# # Kfold with Gaussian Copule

# %%
SEEDS = [42, 30, 2, 1500]

# %%
results = []

for seed in SEEDS:
    set_seed(seed)
    skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=seed)
    
    for train_index, test_index in skf.split(df.loc[:, FEATURE_COLUMNS], 
                                             df.loc[:, LABEL_A]):

        

        df_gen = df.loc[train_index]
        df_gen_positives = df_gen[df_gen[LABEL_A] == 1]
        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=df_gen_positives)
        Gaussian = GaussianCopulaSynthesizer(metadata, default_distribution='norm')
        Gaussian.fit(df_gen_positives)
        generated_data = Gaussian.sample(num_rows = len(df_gen_positives))
        


        X_train, X_test = df.loc[train_index, FEATURE_COLUMNS], df.loc[test_index, FEATURE_COLUMNS]
        y_train, y_test = df.loc[train_index, LABEL_A], df.loc[test_index, LABEL_A]

    # Fit classifier on imbalanced data
        clf = RandomForestClassifier(random_state=seed)
        clf = clf.fit(X_train, y_train)
    # Evaluate classifier on imbalanced data
        y_pred = clf.predict(X_test)
        clf_report = classification_report(y_test, y_pred)
        clf_conf_matrix = confusion_matrix(y_test, y_pred)
        one_metrics_normal = precision_recall_fscore_support(y_test, y_pred, average="binary")
        results.append(["normal"] + list(one_metrics_normal) + [seed])

    # Fit classifier on balanced data
        X_train_syn = np.vstack((X_train, generated_data.loc[:, FEATURE_COLUMNS]))
        y_train_syn = np.hstack((y_train, generated_data.loc[:, LABEL_A]))
        clf_syn = RandomForestClassifier(random_state=seed)
        clf_syn = clf_syn.fit(X_train_syn, y_train_syn)
    # Evaluate classifier on balanced data
        y_pred_syn = clf_syn.predict(X_test)
        clf_report_syn = classification_report(y_test, y_pred_syn)
        clf_conf_matrix_syn = confusion_matrix(y_test, y_pred_syn)
        one_metrics_syn = precision_recall_fscore_support(y_test, y_pred_syn, average="binary")
        results.append(["synthetic"] + list(one_metrics_syn)+ [seed])

df_results_synthia_ind_g = pd.DataFrame(results, columns=["dataset_type","precision", "recall", "f1-score", "support", "seed"]).drop(columns=["support"])

# %%
df_results_synthia_ind_g.groupby(["dataset_type", "seed"]).mean().reset_index().groupby(["dataset_type", "seed"]).mean()
# Out:
#                    precision    recall  f1-score
# dataset_type seed
# normal       2      0.895433  0.584197  0.705248
#              30     0.880226  0.619535  0.725086
#              42     0.877407  0.578183  0.694386
#              1500   0.891463  0.610536  0.723764
# synthetic    2      0.811673  0.628314  0.706649
#              30     0.827624  0.646137  0.723641
#              42     0.832933  0.634109  0.719065
#              1500   0.821500  0.660799  0.731913

# %%
from sklearn.inspection import permutation_importance
o_r = permutation_importance(clf, X_train, y_train, n_repeats=30, random_state=1500)
ag_r = permutation_importance(clf, X_train_syn, y_train_syn, n_repeats=30, random_state=1500)

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
IT = (o_r.importances_mean/ np.max(o_r.importances_mean)).tolist()
ECE = (ag_r.importances_mean/ np.max(ag_r.importances_mean)).tolist()

 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]

 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='original')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='augmented')

 
# Adding Xticks
plt.xlabel('Feature', fontweight ='bold', fontsize = 15)
plt.ylabel('Importance', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        [i for i in df_gen.columns[:-1]], rotation = 45)
 
plt.legend()
plt.show()

# %% [markdown]
# # Kfold with CTGANs

# %%
results = []

for seed in SEEDS:
    set_seed(seed)
    skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=seed)
    
    for train_index, test_index in skf.split(df.loc[:, FEATURE_COLUMNS], 
                                             df.loc[:, LABEL_A]):

        

        df_gen = df.loc[train_index]
        df_gen_positives = df_gen[df_gen[LABEL_A] == 1]
        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=df_gen_positives)
        CTGAN = CTGANSynthesizer(metadata)
        CTGAN.fit(df_gen_positives)
        generated_data = CTGAN.sample(num_rows = len(df_gen_positives))
        


        X_train, X_test = df.loc[train_index, FEATURE_COLUMNS], df.loc[test_index, FEATURE_COLUMNS]
        y_train, y_test = df.loc[train_index, LABEL_A], df.loc[test_index, LABEL_A]

    # Fit classifier on imbalanced data
        clf = RandomForestClassifier(random_state=seed)
        clf = clf.fit(X_train, y_train)
    # Evaluate classifier on imbalanced data
        y_pred = clf.predict(X_test)
        clf_report = classification_report(y_test, y_pred)
        clf_conf_matrix = confusion_matrix(y_test, y_pred)
        one_metrics_normal = precision_recall_fscore_support(y_test, y_pred, average="binary")
        results.append(["normal"] + list(one_metrics_normal) + [seed])

    # Fit classifier on balanced data
        X_train_syn = np.vstack((X_train, generated_data.loc[:, FEATURE_COLUMNS]))
        y_train_syn = np.hstack((y_train, generated_data.loc[:, LABEL_A]))
        clf_syn = RandomForestClassifier(random_state=seed)
        clf_syn = clf_syn.fit(X_train_syn, y_train_syn)
    # Evaluate classifier on balanced data
        y_pred_syn = clf_syn.predict(X_test)
        clf_report_syn = classification_report(y_test, y_pred_syn)
        clf_conf_matrix_syn = confusion_matrix(y_test, y_pred_syn)
        one_metrics_syn = precision_recall_fscore_support(y_test, y_pred_syn, average="binary")
        results.append(["synthetic"] + list(one_metrics_syn)+ [seed])

df_results_synthia_ind = pd.DataFrame(results, columns=["dataset_type","precision", "recall", "f1-score", "support", "seed"]).drop(columns=["support"])

# %%
df_results_synthia_ind.groupby(["dataset_type", "seed"]).mean().reset_index().groupby(["dataset_type", "seed"]).mean()
# Out:
#                    precision    recall  f1-score
# dataset_type seed
# normal       2      0.895433  0.584197  0.705248
#              30     0.880226  0.619535  0.725086
#              42     0.877407  0.578183  0.694386
#              1500   0.891463  0.610536  0.723764
# synthetic    2      0.840894  0.654785  0.735034
#              30     0.825159  0.663521  0.731025
#              42     0.834403  0.654741  0.730617
#              1500   0.828073  0.654960  0.730792

# %%
from sklearn.inspection import permutation_importance
o_r = permutation_importance(clf, X_train, y_train, n_repeats=30, random_state=1500)
ag_r = permutation_importance(clf, X_train_syn, y_train_syn, n_repeats=30, random_state=1500)

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
IT = (o_r.importances_mean/ np.max(o_r.importances_mean)).tolist()
ECE = (ag_r.importances_mean/ np.max(ag_r.importances_mean)).tolist()

 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]

 
# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='original')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='augmented')

 
# Adding Xticks
plt.xlabel('Feature', fontweight ='bold', fontsize = 15)
plt.ylabel('Importance', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        [i for i in df_gen.columns[:-1]], rotation = 45)
 
plt.legend()
plt.show()
